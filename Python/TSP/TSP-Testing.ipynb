# %%
from tsp import TSP

# %%
tsp = TSP((2, 2, 'North'))
tsp.testObstacles()
tsp.calcDubins(2.5, .5)
# Out:
# c:\Users\hiast\Desktop\School\Y2S2\SC2079 - MDP\SC2079-MDP\Python\TSP\dubins.py:524: RuntimeWarning: invalid value encountered in double_scalars
#   *(4*self.radius**2-(intercenter/2)**2)**.5

# %%
tsp.printInfo(2)
# Out:
# [inf, 11.853981633974483, 12.15726815753092, 17.739908981456452, 24.09130104588992, 14.093344306550293]
# [24.439961352133885, 0.5, 23.34013202918584, 18.20006649650916, 14.280972450961723, 26.72516454997271]
# [23.453589980890477, 22.50869852231669, 0.5, 30.29177189408186, 19.413141212198596, 19.60849347759318]
# [9.238808224884306, 14.280972450961723, 7.5936817983812075, 0.5, 23.841723193368022, 9.906804081386497]
# [19.86873619421788, 16.801125492024862, 11.861008693896412, 26.719321040721585, 0.5, inf]
# [14.426990816987242, 29.134954084936208, 13.583748088693717, 24.029621756495587, 28.207963267948966, 0.5]

# %%
sequence, dist = tsp.calcTSP()

# %%
tsp.displayPath(sequence, len(sequence))
# Out:
# [11.853981633974483, (-1.5707963267948966, 1.5707963267948968, 4.0), array([[ 2.        ,  2.        ],
#        [ 2.04983356,  2.49667333],
#        [ 2.19734751,  2.97354586],
#        [ 2.43666096,  3.41160618],
#        [ 2.75823323,  3.79339023],
#        [ 3.14924424,  4.10367746],
#        [ 3.59410561,  4.33009771],
#        [ 4.07508214,  4.46362432],
#        [ 4.57300918,  4.5       ],
#        [ 5.07300918,  4.5       ],
#        [ 5.57300918,  4.5       ],
#        [ 6.07300918,  4.5       ],
#        [ 6.57300918,  4.5       ],
#        [ 7.07300918,  4.5       ],
#        [ 7.57300918,  4.5       ],
#        [ 8.07300918,  4.5       ],
#        [ 8.57299881,  4.50106599],
#        [ 9.06800524,  4.56538092],
#        [ 9.54036709,  4.72675643],
#        [ 9.97125279,  4.97875899],
#        [10.34348429,  5.31134205],
#        [10.64222188,  5.71124657],
#        [10.85555585,  6.16252962],
#        [10.97498124,  6.64719998],
#        [11.        ,  7.        ]])]
# ...
