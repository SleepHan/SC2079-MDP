# %%
from tsp import TSP

# %%
tsp = TSP((2, 2, 'North'))
tsp.testObstacles()

# %%
tsp.calcDubins(2.5, .5)
# Out:
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# Hit wall
# c:\Users\hiast\Desktop\School\Y2S2\SC2079 - MDP\SC2079-MDP\Python\TSP\dubins.py:524: RuntimeWarning: invalid value encountered in double_scalars
#   *(4*self.radius**2-(intercenter/2)**2)**.5

# %%
tsp.printInfo(2)
# Out:
# [inf, inf, 14.563528249242902, inf]
# [22.699327764420715, inf, 16.654156159755118, inf]
# [inf, 13.8427353121709, inf, 7.339049486738293]
# [inf, 18.82300767579509, inf, inf]

# %%
tsp.printInfo(3)
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', 'X', 'S', 'X', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.', '.', '.', '.']
# ...

# %%
sequence, dist = tsp.calcTSP()

# %%
tsp.displayPath(sequence, len(sequence))
# Out:
# [14.563528249242902, (-2.1361308139160506, 3.706927140710947, 1.7088007490635047), array([[ 2.        ,  2.        ],
#        [ 2.05657403,  2.4957067 ],
#        [ 2.22338648,  2.96591873],
#        [ 2.49185802,  3.38645266],
#        [ 2.8481809 ,  3.73568002],
#        [ 3.27402911,  3.99563973],
#        [ 3.74750088,  4.15296181],
#        [ 4.2442451 ,  4.19955504],
#        [ 4.73871375,  4.13302309],
#        [ 5.20547585,  3.95678775],
#        [ 5.63229159,  3.69671694],
#        [ 6.05449632,  3.4288678 ],
#        [ 6.47670106,  3.16101865],
#        [ 6.89990725,  2.89479767],
#        [ 7.35747917,  2.69591659],
#        [ 7.84809655,  2.60525051],
#        [ 8.34652646,  2.62746245],
#        [ 8.82713419,  2.76141004],
#        [ 9.26520164,  3.00020423],
#        [ 9.63819857,  3.33156361],
#        [ 9.92694141,  3.73844605],
#        [10.11657984,  4.1999252 ],
#        [10.19736059,  4.69226677],
#        [10.16512901,  5.19014916],
# ...
