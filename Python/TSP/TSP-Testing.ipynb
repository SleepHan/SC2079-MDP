# %%
from tsp import TSP

# %%
tsp = TSP((2, 2, 'North'))
tsp.testObstacles()
# Out:
# updating
# Test
# updating
# Test
# updating
# Test
# updating
# Test
# updating
# Test

# %%
tsp.calcDubins(2.5, .5)

# %%
tsp.printInfo(3)
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['X', 'X', 'X', '.', '.', '.', 'X', 'S', 'X', '.', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.']
# ['X', 'E', 'X', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.', 'X', 'E', 'X', '.', '.', '.', '.']
# ['X', 'X', 'X', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'X', 'X', 'X', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ...

# %%
sequence, dist = tsp.calcTSP()

# %%
tsp.displayPath(sequence, len(sequence))
